# %%
pwd
# Out:
# 'C:\\Users\\human\\Desktop\\수업자료\\2차'

# %%
# !pip install numpy
# Out:
# ...
#   Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl (12.6 MB)
# ...

# %%
# !pip install pillow

# %%
import os
from glob import glob
from PIL import Image
import numpy as np

# %%
a=[1,2,3,4]
res=[]
for i in a:
    res.append(i*2)
print(res)
# Out:
# [2, 4, 6, 8]

# %%
a=[1,2,3,4]
b=np.array(a)
print(a,type(a))
print(b,type(b))
# Out:
# [1, 2, 3, 4] <class 'list'>
# [1 2 3 4] <class 'numpy.ndarray'>

# %%
a=[1,2,3,4]
b=np.array(a)
print(b)
# Out:
# [1 2 3 4]

# %%
a=[
    [1,2,3],
    [4,5,None]
]
b=np.array(a)
print(b)
# Out:
# [[1 2 3]
#  [4 5 None]]

# %%
a=[
    [1,1,1],
    [2,2,2]
]
s=3
b=[1,2]
arr=np.array(a)
print(arr*s)
print('---------------')
print(arr*b) # b길이가 안맞아서 오류
# Out:
# [[3 3 3]
#  [6 6 6]]
# ---------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 10
#       8 print(arr*s)
#       9 print('---------------')
# ---> 10 print(arr*b)
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,)

# %%
a=[
    [1,1,1],
    [2,2,2]
]
s=3
b=[
    [1],
    [2]
]
arr=np.array(a)
print(arr*s)
print('---------------')
print(arr*b)
# Out:
# [[3 3 3]
#  [6 6 6]]
# ---------------
# [[1 1 1]
#  [4 4 4]]

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x400>

# %%
img=Image.open('./images/강아지5.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x400>

# %%
img=Image.open('./images/강아지1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=377x400>

# %%
file_names=glob('./images/*.jpg')
# file_names
# Out:
# ['./images\\강아지1.jpg',
#  './images\\강아지10.jpg',
#  './images\\강아지2.jpg',
#  './images\\강아지3.jpg',
#  './images\\강아지4.jpg',
#  './images\\강아지5.jpg',
#  './images\\강아지6.jpg',
#  './images\\강아지7.jpg',
#  './images\\강아지8.jpg',
#  './images\\강아지9.jpg',
#  './images\\고양이1.jpg',
#  './images\\고양이2.jpg',
#  './images\\고양이3.jpg',
#  './images\\고양이4.jpg',
#  './images\\고양이5.jpg',
#  './images\\고양이6.jpg']

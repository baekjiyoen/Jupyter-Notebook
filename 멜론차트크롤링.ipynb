# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url='https://www.melon.com/chart/index.htm'
user_agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36'
hdr={
    'User-Agent' : user_agent
}
html=requests.get(url,headers=hdr)
html
# Out:
# <Response [200]>

# %%
pd.read_html(html.text)[0]
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_9516\2544377297.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(html.text)[0]
#     Unnamed: 0    순위      순위등락  앨범이미지 곡 상세가기  \
# 0          NaN    1위  순위 동일  0    NaN    곡정보
# 1          NaN    2위  순위 동일  0    NaN    곡정보
# 2          NaN    3위  순위 동일  0    NaN    곡정보
# 3          NaN    4위  순위 동일  0    NaN    곡정보
# 4          NaN    5위  순위 동일  0    NaN    곡정보
# ..         ...   ...       ...    ...    ...
# 95         NaN   96위  순위 동일  0    NaN    곡정보
# 96         NaN   97위  순위 동일  0    NaN    곡정보
# 97         NaN   98위  순위 동일  0    NaN    곡정보
# 98         NaN   99위  순위 동일  0    NaN    곡정보
# 99         NaN  100위  순위 동일  0    NaN    곡정보
#
#                                  곡정보                                    앨범  \
# 0                 HAPPY  DAY6 (데이식스)                              Fourever
# 1                      내 이름 맑음  QWER  2nd Mini Album 'Algorithm's Blossom'
# 2   Welcome to the Show  DAY6 (데이식스)                              Fourever
# 3                   Supernova  aespa            Armageddon - The 1st Album
# 4         한 페이지가 될 수 있게  DAY6 (데이식스)              The Book of Us : Gravity
# ..                               ...                                   ...
# 95                   꿈  태연 (TAEYEON)                    웰컴투 삼달리 OST Part.3
# 96             Nice Guy  BOYNEXTDOOR                                 19.99
# 97                     OMG  NewJeans                        NewJeans 'OMG'
# 98               Live My Life  aespa            Armageddon - The 1st Album
# 99              그녀가 웃었다  DAY6 (데이식스)                              Band Aid
#
#             좋아요  듣기  담기    다운     뮤비
# 0   좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 1   좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 2   좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 3   좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 4   좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# ..          ...  ..  ..   ...    ...
# 95  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 96  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 97  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 98  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
# 99  좋아요  총건수  0  듣기  담기  다운로드  뮤직비디오
#
# [100 rows x 12 columns]

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------------------- -------------------- 1.8/3.8 MB 10.1 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-5.3.0

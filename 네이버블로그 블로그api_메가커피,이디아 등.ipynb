# %%
import os
import sys
import urllib.request
import matplotlib.pyplot as plt
import json
import numpy as np
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False


#함수 정의

def blog(search)->df:
    # 검색어를 URL 인코딩
    encText = urllib.parse.quote(search)
    
    # 요청할 URL 설정 (JSON 결과 반환)
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText
    
    # 요청할 URL 설정 (XML 결과 반환 시 사용)
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText
    
    # 요청 객체 생성 및 헤더에 클라이언트 ID와 클라이언트 시크릿 추가
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    
    # API 요청 및 응답 받기
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    
    # 응답 코드가 200이면 성공적으로 데이터 받기
    if(rescode==200):
        response_body = response.read()
        response_dict=json.loads(response_body)
        res_df=pd.DataFrame(response_dict['items'])
        
    else:
        print("Error Code:" + rescode)  # 에러 코드 출력
        return
    return res_df

#메인
# 네이버 API 사용자 식별을 위한 ID와 비밀번호
client_id = "jro7pRJVQag6_ygE5WyZ"
client_secret = "001wP06NKO"

res=[]
검색어=['메가커피','이디아','컴포즈','빽다방','스타벅스']
res=[]
for i in 검색어:
    tmp=blog(i)
    tmp['검색어']=i
    res.append(tmp)

# %%
df=pd.concat(res,ignore_index=True)
print(df.shape)
df
# Out:
# (50, 7)
#                                              title  \
# 0        <b>메가커피</b> 제로 아이스티 복숭아 샷추가 (아샷추) 변비에...
# 1     <b>메가커피</b> 9월 신메뉴 귤톡톡 &amp; 밤밤 크리미 가을 추천 음료
# 2          보기 드문 매출을 유지하는 대구 <b>메가커피</b> 창업 (양도양수)
# 3                <b>메가커피</b> 창업비용 저렴하게? 현실을 알려드립니다
# 4             <b>메가커피</b> 메뉴 추천 가을에 어울리는 밤밤 찰떡 프라페
# 5           <b>메가커피</b> 메뉴 아메리카노 사랑의 하츄핑 피규어 실물 후기
# 6                 <b>메가커피</b> 메뉴 추천 할메가미숫커피 칼로리 후기
# 7                     <b>메가커피</b> 창업비용 고매출 양도양수 추천
# 8         <b>메가커피</b> 지구멜론 스무디+ 지구별 초코 크레페 신메뉴 맛보기
# 9                     <b>메가커피</b>할인받기/SK멤버쉽/우주패스혜택
# 10          <b>이디아</b>랩 강남 학동역 언주역 늦게까지 하는 주차가능 카페
# 11    카디드 후츠와 씨앗 &amp; 머쉬룸 수프와 <b>이디아</b>자발 치즈 레시피
# 12          프랜차이즈 커피전문점 경산시 <b>이디아</b> 커피숍 양도양수 매매
# 13       <b>이디아</b> 수박주스(땡모반,땡모빤) 초당옥수수빙수 제로슈가...
# 14        삼악산 호수케이블카 예약 할인요금 전망대 카페 <b>이디아</b> 환상뷰
# 15          청주 더빈 컨벤션 인근 넓고 편안한 카페 <b>이디아</b> 청주역점
# 16        <b>이디아</b>커피 미니펄 밀크티 신메뉴, 가격 칼로리 그리고...
# ...

# %%
res
# Out:
# [                                          title  \
#  0     <b>메가커피</b> 제로 아이스티 복숭아 샷추가 (아샷추) 변비에...
#  1  <b>메가커피</b> 9월 신메뉴 귤톡톡 &amp; 밤밤 크리미 가을 추천 음료
#  2       보기 드문 매출을 유지하는 대구 <b>메가커피</b> 창업 (양도양수)
#  3             <b>메가커피</b> 창업비용 저렴하게? 현실을 알려드립니다
#  4          <b>메가커피</b> 메뉴 추천 가을에 어울리는 밤밤 찰떡 프라페
#  5        <b>메가커피</b> 메뉴 아메리카노 사랑의 하츄핑 피규어 실물 후기
#  6              <b>메가커피</b> 메뉴 추천 할메가미숫커피 칼로리 후기
#  7                  <b>메가커피</b> 창업비용 고매출 양도양수 추천
#  8      <b>메가커피</b> 지구멜론 스무디+ 지구별 초코 크레페 신메뉴 맛보기
#  9                  <b>메가커피</b>할인받기/SK멤버쉽/우주패스혜택
#
#                                                 link  \
#  0        https://blog.naver.com/nddoo_/223599827308
#  1     https://blog.naver.com/yuna_1024/223577650649
#  2  https://blog.naver.com/sunghyun3152/223597199896
#  3    https://blog.naver.com/iameunhee3/223594933691
#  4    https://blog.naver.com/darkyoon85/223578269584
#  5    https://blog.naver.com/kangsy0203/223578896323
# ...

# %%
plt.bar(x=검색어[:-1], height=res[:-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 plt.bar(x=검색어[:-1], height=res[:-1])
#
# File ~\.conda\envs\edu\Lib\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
#    2963         **kwargs,
#    2964     )
#
# File ~\.conda\envs\edu\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
# ...

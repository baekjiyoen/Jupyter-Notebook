# %%
from PIL import Image
from glob import glob

# %%
# 파일 목록 가져오기 (새로운 창으로 뜸)
file_names=glob('./images/*.jpg')
for file_name in file_names:
    img=Image.open(file_name) # 이미지 불러오기
    # img.show()
    print(f'이미지 파일 이름 : {img.filename}')
    print(f'이미지 파일형식(format) : {img.format}')
    print(f'이미지 용량(size) : {img.size}')
    print(f'이미지 색상모드 : {img.mode}')
    print(f'이미지 width : {img.width}')
    print(f'이미지 height : {img.height}') 
    print('-------------------------------------')
# Out:
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지1.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (377, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 377
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지10.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (599, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 599
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지2.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (584, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 584
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지3.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (433, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 433
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지4.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (356, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 356
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지5.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (564, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 564
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지6.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (533, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 533
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지7.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (537, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 537
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지8.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (533, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 533
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\강아지9.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (510, 400)
# 이미지 색상모드 : RGB
# 이미지 width : 510
# 이미지 height : 400
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\고양이1.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (683, 512)
# 이미지 색상모드 : RGB
# 이미지 width : 683
# 이미지 height : 512
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\고양이2.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (650, 433)
# 이미지 색상모드 : RGB
# 이미지 width : 650
# 이미지 height : 433
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\고양이3.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (819, 512)
# 이미지 색상모드 : RGB
# 이미지 width : 819
# 이미지 height : 512
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\고양이4.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (500, 321)
# 이미지 색상모드 : RGB
# 이미지 width : 500
# 이미지 height : 321
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\고양이5.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (683, 512)
# 이미지 색상모드 : RGB
# 이미지 width : 683
# 이미지 height : 512
# -------------------------------------
# 이미지 파일 이름 : C:\Users\human\Desktop\수업자료\2차\images\고양이6.jpg
# 이미지 파일형식(format) : JPEG
# 이미지 용량(size) : (600, 375)
# 이미지 색상모드 : RGB
# 이미지 width : 600
# 이미지 height : 375
# -------------------------------------

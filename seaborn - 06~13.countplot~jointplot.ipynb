# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
print(df.shape)
df.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['adult_male'].value_counts()
# Out:
# adult_male
# True     537
# False    354
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
cols=['survived','age', 'sibsp', 'parch','adult_male','alone']
df[cols].corr().sort_values('survived')
# Out:
#             survived       age     sibsp     parch  adult_male     alone
# adult_male -0.557080  0.280328 -0.253586 -0.349943    1.000000  0.404744
# alone      -0.203367  0.198270 -0.584471 -0.583398    0.404744  1.000000
# age        -0.077221  1.000000 -0.308247 -0.189119    0.280328  0.198270
# sibsp      -0.035322 -0.308247  1.000000  0.414838   -0.253586 -0.584471
# parch       0.081629 -0.189119  0.414838  1.000000   -0.349943 -0.583398
# survived    1.000000 -0.077221 -0.035322  0.081629   -0.557080 -0.203367

# %%
df['alone'].sum()
# Out:
# np.int64(537)

# %%
df.groupby(['parch','sibsp'])['survived'].count()
# Out:
# parch  sibsp
# 0      0        537
#        1        123
#        2         16
#        3          2
# 1      0         38
#        1         57
#        2          7
#        3          7
#        4          9
# 2      0         29
#        1         19
#        2          4
#        3          7
#        4          9
#        5          5
#        8          7
# 3      0          1
#        1          3
#        2          1
# 4      0          1
#        1          3
# 5      0          2
#        1          3
# 6      1          1
# Name: survived, dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[df['alone']]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [537 rows x 15 columns]

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
# 1. 각 class별 who의 인원을 그래프로 그려 보세요

# %%
sns.countplot(x='class',data=df,hue='who')
plt.show()

# %%
import numpy as np

# %%
x = np.random.randn(100)
x
# Out:
# array([-1.06908226, -0.15339421,  1.54342241, -0.65613074,  0.13603203,
#         1.28709825,  0.0479822 , -0.02713122, -1.36097787,  0.06276673,
#        -1.11962742,  0.78272209,  0.7756467 ,  1.05689099,  1.94219564,
#         0.51036154,  0.90921305, -0.40191161,  0.34672246,  0.01497805,
#         0.69690013, -0.89364156,  1.02286427, -0.0513779 ,  0.11500152,
#         0.35796359, -1.63300504, -0.30575681,  0.8868259 ,  1.94837193,
#        -1.43528137, -1.04970821, -0.40210978,  1.03005378,  1.44982368,
#         1.61637083,  0.071158  , -0.676571  , -1.06868373,  0.23264671,
#         0.01497409,  0.06099284, -1.2530407 ,  0.7898747 , -1.39319717,
#         0.81209943,  0.49564047,  0.35019863,  0.58810904,  2.62079439,
#        -0.04220078, -1.60046289,  0.89376212, -0.79673568,  2.00003813,
#         0.14045317, -0.24342259,  0.51283377, -0.24754997, -0.00742095,
#         0.76293102,  0.30359114, -1.40143788,  0.40854652,  0.96671762,
#        -3.05903635,  0.52638825,  0.79707128, -0.10477233, -0.22330297,
#         2.10097204, -1.23334411, -1.9799181 ,  0.09950324, -0.44464251,
#         1.75121956, -1.09746133,  0.41409663, -1.15959933, -0.31370174,
#        -0.07999919,  0.00643245, -0.09730213,  0.74681793, -1.19075191,
#         0.09866416,  0.36196936, -0.6085656 , -1.42458043, -0.13016051,
#        -0.67149463, -0.65671643,  1.38364516, -1.80563801,  1.71021033,
#         0.52754766,  0.60614817, -0.20403978,  0.1222085 ,  0.71839759])

# %%
sns.distplot(x, rug=False,kde=True)
plt.show()
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_14768\1416355516.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, rug=False,kde=True)

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.pairplot(df,hue='sex')

# %%
# sns.pairplot(df,hue='size')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='sex',row='day',col='time')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sns.lmplot(x='total_bill', y='tip', data=df, hue='sex',row='day',col='time')
#
# File ~\.conda\envs\edu\Lib\site-packages\seaborn\regression.py:611, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     609 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     610 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 611 data = data[cols]
#     613 # Initialize the grid
#     614 facets = FacetGrid(
#     615     data, row=row, col=col, hue=hue,
#     616     palette=palette,
#    (...)
#     619     **facet_kws,
#     620 )
#
# File ~\.conda\envs\edu\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\.conda\envs\edu\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\.conda\envs\edu\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['day', 'time', 'tip', 'total_bill'] not in index"

# %%
sns.jointplot(x='total_bill',y='tip',data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 sns.jointplot(x='total_bill',y='tip',data=df)
#
# File ~\.conda\envs\edu\Lib\site-packages\seaborn\axisgrid.py:2243, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2240     dropna = True
#    2242 # Initialize the JointGrid object
# -> 2243 grid = JointGrid(
#    2244     data=data, x=x, y=y, hue=hue,
#    2245     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2246     dropna=dropna, height=height, ratio=ratio, space=space,
#    2247     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2248 )
#    2250 if grid.hue is not None:
#    2251     marginal_kws.setdefault("legend", False)
#
# File ~\.conda\envs\edu\Lib\site-packages\seaborn\axisgrid.py:1728, in JointGrid.__init__(self, data, x, y, hue, height, ratio, space, palette, hue_order, hue_norm, dropna, xlim, ylim, marginal_ticks)
#    1725     ax_marg_y.xaxis.grid(False)
#    1727 # Process the input variables
# -> 1728 p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1729 plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1731 # Possibly drop NA
#
# File ~\.conda\envs\edu\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~\.conda\envs\edu\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~\.conda\envs\edu\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~\.conda\envs\edu\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `total_bill` for `x`. An entry with this name does not appear in `data`.

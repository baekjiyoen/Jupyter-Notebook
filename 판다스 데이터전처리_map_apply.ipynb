# %%
# 함수를 만들어 데이터프레임에 적용하려면 ->for, map, apply

# %%
pwd
# Out:
# 'C:\\Users\\human\\Desktop\\수업자료\\데이터분석&시각화\\01판다스'

# %%
import pandas as pd

# %%
df=pd.read_csv('./data/seoul_house_price.csv')
print(df.shape)
df.head()
# Out:
# (4505, 5)
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울                 전체  2015  10    5841
# 1  서울         전용면적 60㎡이하  2015  10    5652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4  서울        전용면적 102㎡초과  2015  10    5879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3293 entries, 0 to 3292
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      3293 non-null   object
#  1   규모      3293 non-null   object
#  2   연도      3293 non-null   int64
#  3   월       3293 non-null   int64
#  4   분양가     3293 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 128.8+ KB

# %%
df.dtypes
# Out:
# 지역     object
# 규모     object
# 연도      int64
# 월       int64
# 분양가     int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# 지역     0
# 규모     0
# 연도     0
# 월      0
# 분양가    0
# dtype: int64

# %%
df.colums=['지역','규모','연도','월','분양가격']
df.head()
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_8536\2531463391.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.colums=['지역','규모','연도','월','분양가격']
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울                 전체  2015  10    5841
# 1  서울         전용면적 60㎡이하  2015  10    5652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4  서울        전용면적 102㎡초과  2015  10    5879

# %%
# 분양가격 컬럼을 int로 바꾸기 -> ,는삭제하고, 나머지는 None으로 하기
def number_t(value:str):
    try:
        res=int(value.replace(',',''))
    except:
        res=None
    return res
#1. for문-1
res=[]
for i in df['분양가격']:
    res.append(number_t(i))
print(res)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\edu\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '분양가격'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 10
#       8 #1. for문-1
#       9 res=[]
# ---> 10 for i in df['분양가격']:
# ...

# %%
#2. for문-1
res1=[number_t(i) for i in df['분양가격']]
print(res1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\edu\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '분양가격'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 #2. for문-1
# ----> 2 res1=[number_t(i) for i in df['분양가격']]
# ...

# %%
#2.map
df1['분양가격'].map(number_t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 #2.map
# ----> 2 df1['분양가격'].map(number_t)
#
# NameError: name 'df1' is not defined

# %%
df.head()
# Out:
#    지역             규모    연도   월   분양가
# 0  서울          60㎡이하  2015  10  5652
# 1  서울    60㎡초과 85㎡이하  2015  10  5882
# 2  서울   85㎡초과 102㎡이하  2015  10  5721
# 3  서울         102㎡초과  2015  10  5879
# 4  인천          60㎡이하  2015  10  3488

# %%
df['규모'].map(lambda x:x.replace('㎡',''))
# Out:
# 0              60이하
# 1         60초과 85이하
# 2        85초과 102이하
# 3             102초과
# 4              60이하
#            ...
# 3288      60초과 85이하
# 3289     85초과 102이하
# 3290           60이하
# 3291      60초과 85이하
# 3292          102초과
# Name: 규모, Length: 3293, dtype: object

# %%
for i in df[['연도','월']]:
    tmp=[]
    for j in df[i]:
        tmp.append(str(j)+'원')
    res.append(tmp)
print(res)
# Out:
# [['2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원', '2015원
# ...

# %%
df.head()
# Out:
#    지역             규모    연도   월   분양가
# 0  서울          60㎡이하  2015  10  5652
# 1  서울    60㎡초과 85㎡이하  2015  10  5882
# 2  서울   85㎡초과 102㎡이하  2015  10  5721
# 3  서울         102㎡초과  2015  10  5879
# 4  인천          60㎡이하  2015  10  3488

# %%
df[['연도','월']]=df[['연도','월']].map(lambda x:int(x.replace('원','')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df[['연도','월']]=df[['연도','월']].map(lambda x:int(x.replace('원','')))
#
# File ~\.conda\envs\edu\Lib\site-packages\pandas\core\frame.py:10468, in DataFrame.map(self, func, na_action, **kwargs)
#   10465 def infer(x):
#   10466     return x._map_values(func, na_action=na_action)
# > 10468 return self.apply(infer).__finalize__(self, "map")
#
# File ~\.conda\envs\edu\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# ...

# %%
df.dtypes
# Out:
# 지역     object
# 규모     object
# 연도      int64
# 월       int64
# 분양가     int64
# dtype: object

# %%
df.head()
# Out:
#    지역             규모    연도   월   분양가
# 0  서울          60㎡이하  2015  10  5652
# 1  서울    60㎡초과 85㎡이하  2015  10  5882
# 2  서울   85㎡초과 102㎡이하  2015  10  5721
# 3  서울         102㎡초과  2015  10  5879
# 4  인천          60㎡이하  2015  10  3488

# %%
df=pd.read_csv('./data/korean-idol.csv')
print(df.shape)
df.head()
# Out:
# (15, 8)
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df[df.isnull().any(axis=1)]
# Out:
#       이름    그룹  소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 2   강다니엘   NaN  커넥트  남자  1996-12-10  180.0   A  8273745
# 7     소연   아이들   큐브  여자  1998-08-26    NaN   B  4668615
# 10    태연  소녀시대   SM  여자  1989-03-09    NaN   A  3918661

# %%
df[df['그룹'].insull()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df[df['그룹'].insull()]
#
# File ~\.conda\envs\edu\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'insull'

# %%
df1=pd.read_csv('./data/train.csv')
print(df1.shape)
df1.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df1.isnull().sort_values('Cabin'))
# Out:
# <Axes: >

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
'''
판다스 객체, fillna()
1. 특정값으로 채우기 : 0,평균, 중앙값, 최빈값...
2. 위쪽 데이터, 아래쪽데이터, 특정 컬럼의 데이터

'''
# Out:
# '\n판다스 객체, fillna()\n1. 특정값으로 채우기 : 0,평균, 중앙값, 최빈값...\n2. 위쪽 데이터, 아래쪽데이터, 특정 컬럼의 데이터\n\n'

# %%
df.fillna(0)
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘      0      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    0.0   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    0.0   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df['키'].mean()
# Out:
# np.float64(175.7923076923077)

# %%
df['키1']=df['키'].fillna(df['키'].mean())
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수          키1
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  173.600000
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947  177.000000
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745  180.000000
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  178.000000
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928  162.100000
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  178.000000
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792  182.300000
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615  175.792308
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  179.200000
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489  167.100000
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661  175.792308
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027  183.000000
# ...

# %%
df['키2']=df['키'].fillna(df.groupby('성별')['키'].mean()['여자'])
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수          키1  \
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  173.600000
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947  177.000000
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745  180.000000
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  178.000000
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928  162.100000
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  178.000000
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792  182.300000
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615  175.792308
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  179.200000
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489  167.100000
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661  175.792308
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027  183.000000
# ...

# %%
df['그룹1']=df['그룹'].fillna(df['그룹'].value_counts().head(1).index[0])
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수          키1  \
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  173.600000
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947  177.000000
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745  180.000000
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  178.000000
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928  162.100000
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  178.000000
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792  182.300000
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615  175.792308
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  179.200000
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489  167.100000
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661  175.792308
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027  183.000000
# ...

# %%
df['그룹2']=df['그룹'].fillna(df['이름'])
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수          키1  \
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  173.600000
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947  177.000000
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745  180.000000
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  178.000000
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928  162.100000
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  178.000000
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792  182.300000
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615  175.792308
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  179.200000
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489  167.100000
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661  175.792308
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027  183.000000
# ...

# %%
df.dropna()
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수     키1     키2  \
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  173.6  173.6
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947  177.0  177.0
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  178.0  178.0
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928  162.1  162.1
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  178.0  178.0
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792  182.3  182.3
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  179.2  179.2
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489  167.1  167.1
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027  183.0  183.0
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654  175.0  175.0
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137  176.0  176.0
# ...

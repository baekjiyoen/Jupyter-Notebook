# %%
pwd
# Out:
# 'C:\\Users\\human\\Desktop\\수업자료\\데이터분석&시각화\\05 크롤링_01'

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\human\.conda\envs\edu\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\human\.conda\envs\edu\lib\site-packages (from beautifulsoup4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url='https://kin.naver.com/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&page=1'
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\t\n\t\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n<meta name="referrer" contents="always">\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="description" content="전세사기의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN &#039;질문하기&#039;를 해보세요."/>\n<meta name="viewport" content="width=1024">\n\n<meta name="msapplication-config" content="none" />\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/css/min/common.css" />\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/css/min/components.css" />\n\n\n\t\n\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/css/min/other.css">\n\t\n\n\n\n\n\n\n<script>\n\t\n\tvar pcDomain = "kin.naver.com";\n\tvar pcDomainWithProtocol = "https://kin.naver.com";\n\tvar pcKinServiceProtocol = "https";\n\n\tvar mobileDomain = "m.kin.naver.com";\n\tvar mobileDomainWithProtocol = "https://m.kin.naver.com";\n\tvar mobileKinServiceProtocol = "https";\n\n\tvar uploadDomain = "upload.kin.naver.com";\n\tvar uploadDomainWithProtocol = "https://upload.kin.naver.com";\n\tvar uploadKinServiceProtocol = "https";\n</script>\n\n\n\t<script type="text/javascript" src="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/js/min/kin.js"></script>\n\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n\n\t\n\t\n\t\n\t\t<meta name="robots" content="noindex,nofollow" />\n\t\n\n\n\n\n\n\t\n\n\n\n<meta property="og:title" content="전세사기 검색결과 : 네이버 지식iN"/>\n\n\n\t<meta property="og:url" content="https://kin.naver.com/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&page=1"/>\n\n\n\n\t<meta property="og:image" content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png"/>\n\n<meta property="og:description" content="전세사기의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN &#039;질문하기&#039;를 해보세요."/>\n<meta property="og:article:author" content="네이버 지식iN"/>\n<meta property="og:article:author:url" content="https://kin.naver.com"/>\n\n<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?v=2.4">\n<title>\n\t전세사기 검색결과 : 지식iN\n</title>\n\n<script type="text/javascript">\n\nif ( typeof window.nhn  == "undefined" ) window.nhn = {};\nif ( typeof window.naver  == "undefined" ) window.naver = {};\nnhn.isLogin = false;\nnhn.isJunior = ("N"=="Y");\nnhn.isKinUser = false;\nnhn.isPortableDevice = false;\nnhn.jsDir = \'https://ssl.pstatic.net/static.kin/static/pc/20240925134013/js/min\';\n\nvar g_ssc = ("kin.search" == "") ? "kin.temp" : "kin.search";\nvar ccsrv="cc.naver.com";\n\n\nvar kinRos = {\n\tbIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,\n\tbIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true\n\n};\n\n\n\n\n\nvar standardReportPopupUrl = "https://srp2.naver.com/report";\n\n\nvar baUserKey = "__UNKNOWN__";\nvar baLogEndpoint = "https://scv-kin.io.naver.com/jackpotlog/v1/logs";\nvar baAbTestResult = null;\n</script>\n\n</head>\n\n\n<body>\n\t\n\t<div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">\n\t\t<img src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" width="21" height="21" alt="데이터 요청 응답 대기중" style="position:absolute;top:49%;left:49%;">\n\t</div>\n\t<div id="wrap" class="wrap wrap_search"> \n\t\n\n\n<div class="skip_nav header_gnb_inner">\n\n\t<a href="#gnb" onclick="nhn.Kin.Utility.skipNavigation(\'au_lnb_home\');return false;" class="skip">메인 메뉴 바로가기</a>\n\t\n\n \n\t<a href="#s_content" onclick="nhn.Kin.Utility.skipNavigation(\'s_content\');return false;" class="skip">본문 바로가기</a>\n\n\n</div>\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<div class="header_wrap">\n\n\t\n\t\n\n\n\n\n\n\n\n\n\t\n\t\n\ ...

# %%
soup=bs(response.text,'html')
type(soup),soup
# Out:
# (bs4.BeautifulSoup,
#
#  <!DOCTYPE html>
#
#  <html lang="ko">
#  <head>
#  <meta contents="always" name="referrer"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="전세사기의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN '질문하기'를 해보세요." name="description">
#  <meta content="width=1024" name="viewport"/>
#  <meta content="none" name="msapplication-config">
#  <link href="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/css/min/common.css" rel="stylesheet" type="text/css"/>
#  <link href="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/css/min/components.css" rel="stylesheet" type="text/css"/>
#  <link href="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/css/min/other.css" rel="stylesheet" type="text/css"/>
#  <script>
#
#  	var pcDomain = "kin.naver.com";
#  	var pcDomainWithProtocol = "https://kin.naver.com";
#  	var pcKinServiceProtocol = "https";
#
#  	var mobileDomain = "m.kin.naver.com";
#  	var mobileDomainWithProtocol = "https://m.kin.naver.com";
#  	var mobileKinServiceProtocol = "https";
#
#  	var uploadDomain = "upload.kin.naver.com";
#  	var uploadDomainWithProtocol = "https://upload.kin.naver.com";
#  	var uploadKinServiceProtocol = "https";
#  </script>
#  <script src="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/js/min/kin.js" type="text/javascript"></script>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="noindex,nofollow" name="robots">
#  <meta content="전세사기 검색결과 : 네이버 지식iN" property="og:title">
#  <meta content="https://kin.naver.com/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=1" property="og:url"/>
#  <meta content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png" property="og:image"/>
#  <meta content="전세사기의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN '질문하기'를 해보세요." property="og:description"/>
#  <meta content="네이버 지식iN" property="og:article:author"/>
#  <meta content="https://kin.naver.com" property="og:article:author:url"/>
#  <link href="/favicon.ico?v=2.4" rel="shortcut icon" type="image/x-icon"/>
#  <title>
#  	전세사기 검색결과 : 지식iN
#  </title>
#  <script type="text/javascript">
#
#  if ( typeof window.nhn  == "undefined" ) window.nhn = {};
#  if ( typeof window.naver  == "undefined" ) window.naver = {};
#  nhn.isLogin = false;
#  nhn.isJunior = ("N"=="Y");
#  nhn.isKinUser = false;
#  nhn.isPortableDevice = false;
#  nhn.jsDir = 'https://ssl.pstatic.net/static.kin/static/pc/20240925134013/js/min';
#
#  var g_ssc = ("kin.search" == "") ? "kin.temp" : "kin.search";
#  var ccsrv="cc.naver.com";
#
#
#  var kinRos = {
#  	bIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,
#  	bIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true
#
#  };
#
#
#
#
#
#  var standardReportPopupUrl = "https://srp2.naver.com/report";
#
#
#  var baUserKey = "__UNKNOWN__";
#  var baLogEndpoint = "https://scv-kin.io.naver.com/jackpotlog/v1/logs";
#  var baAbTestResult = null;
#  </script>
#  </meta></meta></meta></meta></head>
#  <body>
#  <div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">
#  <img alt="데이터 요청 응답 대기중" height="21" src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" style="position:absolute;top:49%;left:49%;" width="21"/>
#  </div>
#  <div class="wrap wrap_search" id="wrap">
#  <div class="skip_nav header_gnb_inner">
#  <a class="skip" href="#gnb" onclick="nhn.Kin.Utility.skipNavigation('au_lnb_home');return false;">메인 메뉴 바로가기</a>
#  <a class="skip" href="#s_content" onclick="nhn.Kin.Utility.skipNavigation('s_content');return false;">본문 바로가기</a>
#  </div>
#  <div class="header_wrap">
#  <div aria-labelledby="ieUpdateBannerTitle" class="popup popup--header_notice" id="ieUpdateBanner" role="dialog" style="display: none;">
#  <h1 class="blind" id="ieUpdateBannerTitle" tabindex="0">권장 브라우저 업데이트 안내</h1>
#  <div class="popup__content">
#  <div class="popup__title">
#  <p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>
#  </div>
#  <div class="popup__maintext">
#  <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>
#  <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>
#  </div>
#  </div>
#  </div>
#  <script type="text/javascript">
#  	// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.
#  	$Fn(function() {
#  		var oAgent = jindo.$Agent().navigator();
#  		if (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {
#  			if (typeof naver.kin.SimpleBanner !== "undefined") {
#  				var oIeUpdateBanner = new naver.kin.SimpleBanner({
#  					sBannerId: "ieUpdateBannerArea"
#  				});
#  			}
#  		}
#  	}, this).attach(document, 'domready');
#  </script>
#  <div class="header_gnb">
#  <div class="header_gnb_inner">
#  <div class="header_gnb__cell">
#  <h1 class="header_logo">
#  <a class="logo_naver" href="http://www.naver.com" onclick="nhn.Kin.Utility.nClicks('STA.naverlogo', '', '', event);" title="나의 경쟁력, 네이버"><span class="blind">NAVER</span></a>
#  </h1>
#  <div class="header_search">
#  <h2 class="logo_wrap">
#  <a class="icon_logo_kin" href="/" onclick="nhn.Kin.Utility.nClicks('STA.kin', '', '', event);"><span class="blind">지식iN</span></a>
#  </h2>
#  <h3 class="blind">검색영역</h3>
#  <form action="/search/list.naver" id="topSearch" method="get" name="topSearch" onsubmit="return checkQuery();">
#  <fieldset>
#  <legend>지식인 검색</legend>
#  <div class="search_area">
#  <input accesskey="s" aria-autocomplete="list" aria-controls="atcmpList" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="search_input" id="nx_query" maxlength="255" name="query" onclick="nhn.Kin.Utility.nClicks('STA.search', '', '', event);return false;" role="combobox" title="검색어 입력" type="text" value="전세사기"/>
#  <a class="search_auto" href="#">
#  <span class="sp_gnb icon_arrow" id="triangleBtn">자동완성 열기</span>
#  </a>
#  <div>
#  <iframe class="auto_complete_box" frameborder="0" height="193px" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" title="검색어 자동완성" width="290"></iframe>
#  </div>
#  <a class="search_btn" href="#" onclick="return checkQuery();"><span class="sp_gnb icon_search">지식iN 검색</span></a>
#  </div>
#  </fieldset>
#  </form>
#  </div>
#  </div>
#  <div class="header_gnb__cell">
#  <div class="gnb_wrap">
#  <div class="gnb_eXpertLogo">
#  <a aria-controls="bannerExpert" aria-expanded="true" aria-haspopup="true" class="link" href="https://expert.naver.com" id="bannerLink" target="_blank">
#  <span class="logo"><span class="blind">eXpert</span></span>
#  </a>
#  </div>
#  <div class="gnb_common_area">
#  <div id="gnb">
#  <script type="text/javascript">
#
#  								var gnb_service = "kin";
#
#  								var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
#  								var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
#  								var gnb_template = "gnb_utf8";
#
#  								var gnb_item_hide_option = 0;
#
#
#
#
#  							</script>
#  <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2024100714" type="text/javascript"></script>
#  </div>
#  </div>
#  </div>
#  <div class="header__rolling rolling-notice">
#  <i class="icon_speaker"><span class="blind">실시간 공지사항</span></i>
#  <ul class="rolling-notice__list _rolling_banner" id="listNotice">
#  <li class="rolling-notice__item _rollingItem" data-start-time="2023-07-03 00:00:00" style="display:none;">
#  <a class="rolling-notice__link" href="https://m.expert.naver.com/mobile/expert/account/join/hub" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
#  <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
#  <span class="text-color--secondary">지식iN은 누구나 엑스퍼트</span><br/>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- nav -->
#  <div class="nav" role="navigation">
#  <div class="nav_inner">
#  <h3 class="blind">메인 메뉴</h3>
#  <ul class="nav_list" id="au_lnb" role="menubar">
#  <li class="menu" role="presentation">
#  <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
#  </li>
#  <li class="menu" role="presentation">
#  <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
#  <ul class="nav_sub_list _lnbSubMenu" role="menu">
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">컴퓨터통신</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
#  <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
#  </ul>
#  </li>
#  <li class="menu" role="presentation">
#  <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
#  </li>
#  <li class="menu" role="presentation">
#  <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
#  </li>
#  <li class="menu" role="presentation">
#  <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
#  </li>
#  <li class="menu" role="presentation">
#  <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
#  </li>
#  <li class="menu" role="presentation">
#  <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
#  </li>
#  <li class="menu" role="presentation">
#  <span class="lnb_bar">|</span>
#  <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
#  </li>
#  <li class="menu" role="presentation">
#  <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
#  </li>
#  <li class="menu" role="presentation">
#  <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
#  </li>
#  </ul>
#  <a class="nav__button_question _clickcode:LNB.q" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver', '');sendBaLog(BaPcEventType.KIN_HOME_5048)" role="button"><span class="btn_inner"><i class="sp_gnb icon_pencil"></i>질문하기</span></a>
#  </div>
#  </div>
#  </div>
#  <script type="text/javascript">
#
#  	$Fn(function() {
#  		new naver.kin.LNB({
#  			'questionType' : ''
#  		});
#  	}).attach(window, 'load');
#
#  	var GNB_BRIGHTNESS_VALUE = {
#  		DARK_ICON : 0,
#  		DARK_ICON_AND_TRANSPARENCY : 1,
#  		BRIGHT_ICON_AND_TRANSPARENCY : 2,
#  		BRIGHT_ICON : 3
#  	};
#
#  	var GNB_ITEM_HIDE_OPTION_BIT_VALUE = {
#  		DEFAULT : 0,
#  		HIDE_LOGIN_BTN : 1,
#  		HIDE_USER_LAYER : 2,
#  		HIDE_NAVER_ME_AREA : 4,
#  		HIDE_MAIL_ALARM_AREA : 8,
#  		HIDE_PROFILE_IMAGE : 16,
#  		SHOW_BENEFIT_FOR_STAFF_MEMBER : 32
#  	};
#
#
#  	var smartSearch = "";
#
#  	var gnb_service = "kin";
#
#  	var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
#  	var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
#  	var gnb_template = "gnb_utf8";
#
#  	var gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;
#
#
#
#
#
#  	$Fn(function() {
#
#  		getGNB();
#
#  		var bIsGnbClicked = false;
#
#
#  		$Fn(function (we) {
#  			if (!bIsGnbClicked) {
#  				gnbAllLayerClose();
#  			}
#
#  			bIsGnbClicked = false;
#  		}, this).attach(document.body, 'click');
#
#  		$Fn(function(we) {
#  			bIsGnbClicked = true;
#  		}, this).attach($('gnb'), 'click');
#
#
#  		try {
#  			$('autoFrame').src = '/static/reatcmp.html?v=4.1';
#  		} catch(e) {
#  		}
#
#  		smartSearch = new nhn.AjaxSuggestUS('nx_query', 'autoFrame', {
#  			url : 'https://ac.search.naver.com/nx/ac',
#  			cookieName : 'NaverSuggestUse',
#  			listbox : '_resultBox',
#  			sFromName : 'topSearch',
#  			triangleBtn : 'triangleBtn',
#  			sListMaxLength : 55,
#  			listMaxCount : 15,
#  			request_type : 'jsonp',
#  			request_data : {
#  				q : '{query}',
#  				st : '100',
#  				r_format : 'json',
#  				t_koreng : '1',
#  				q_enc : 'UTF-8',
#  				r_enc : 'UTF-8',
#  				r_unicode : '0',
#  				r_escape : '1',
#  				frm : 'kin'
#  			},
#  			sTriangleUpOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_up.gif',
#  			sTriangleUpOff : 'https://ssl.pstatic.net/sstatic/search/mypocket/v3/btn_atcmp_off_op2.gif',
#  			sTriangleDownOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down.gif',
#  			sTriangleDownOff : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down3.gif'
#  		}).attach({
#  			actSubmit : function() {
#  				try {
#  					top.selectAction(this._elForm);
#  				} catch(e) {
#  					try {
#  						selectAction(this._elForm);
#  					} catch(e) {
#  					}
#  				}
#
#  				this._elForm.submit();
#  			}
#  		});
#
#  		var expertEntryBanner = $$.getSingle("div.gnb_eXpertLogo div.banner");
#  		if (!!expertEntryBanner) {
#  			var cookie = new $Cookie();
#
#  			$Fn(function () {
#  				$Element(expertEntryBanner).hide();
#
#  				var newDisabledUntil = new Date().getTime() + (3 * 1000 * 24 * 60 * 60);
#  				cookie.set("kin_expert_entry_banner_disabled_until", newDisabledUntil, 5);
#  			}).attach($$.getSingle("div.gnb_eXpertLogo div.banner button.buttonCancel"), 'click');
#
#  			var disabledUntilTimestamp = new Number(cookie.get("kin_expert_entry_banner_disabled_until"));
#  			if (!isNaN(disabledUntilTimestamp)) {
#  				if (new Date().getTime() > disabledUntilTimestamp) {
#  					cookie.remove("kin_expert_entry_banner_disabled_until");
#  					$Element(expertEntryBanner).show();
#  				}
#  			} else {
#  				$Element(expertEntryBanner).show();
#  			}
#  		}
#
#
#  		if (typeof nhn.Kin.ChatMenu !== "undefined") {
#  			window.oChatMenu = new nhn.Kin.ChatMenu();
#  		}
#  	}).attach(window, 'load');
#  </script>
#  <div class="container-fluid" id="container">
#  <div class="container-fluid-content">
#  <div class="container-fluid-content-inner">
#  <div id="search_result">
#  <strong>'전세사기'</strong> 에 대한 검색결과입니다.
#
#
#
#  </div>
#  <script type="text/javascript">
#  function checkAdultAuth() {
#  	var url = "https://" + top.location.hostname + "/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&cs=utf8&section=kin&excludeAdultDoc=false";
#  	var surl = "https://" + top.location.hostname + "/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&cs=utf8&section=kin";
#
#  	try{
#
#
#  			top.location.href = "https://nid.naver.com/nidlogin.login?svctype=128&a_version=2&viewtype=2&url=" + encodeURIComponent(url + "&from=search") + "&surl=" + encodeURIComponent(surl);
#
#  	} catch (e){
#  		history.back();
#  	}
#  }
#  </script>
#  <div class="container-fluid-content__left" id="content">
#  <script src="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/js/min/nhn.Kin.Search.Terms.js" type="text/javascript"></script>
#  <div id="s_content">
#  <div id="scl">
#  <ul>
#  <li class="tx_depth1"><strong><a class="_nclicks:tab.kin" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=kin" title="전체"><span>전체</span></a></strong></li>
#  <li class="tx_depth2"><a class="_nclicks:tab.qna" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna" title="Q&amp;A"><span>Q&amp;A</span></a></li>
#  <li class="tx_depth3"><a class="_nclicks:tab.ency" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=ency" title="오픈백과"><span>오픈백과</span></a></li>
#  <li>
#  </li></ul>
#  </div>
#  <div class="banner_suicide_stop" id="suicidalPreventionBanner" style="display:none;">
#  <div class="content_suicide_stop">
#  <h3 class="tit_suicide_stop">
#  <span class="blind">생명은 소중합니다.! 지금,희망을 클릭하세요.</span>
#  </h3>
#  <ul class="info_suicide_stop">
#  <li class="counsel_list v1">
#  <strong class="tit_counsel_list">전화상담</strong>
#  <ul class="counsel_info_list">
#  <li>자살예방상담전화 <em>109</em></li>
#  <li>정신건강상담전화 <em>1577-0199</em></li>
#  <li><a href="https://www.cyber1388.kr:447" target="_blank">청소년 HelpCall</a> <em>1388</em></li>
#  <li><a href="https://www.lifeline.or.kr" target="_blank">한국생명의전화</a> <em>1588-9191</em></li>
#  <li>한마음한몸자살예방센터 <em>1577-0199</em></li>
#  </ul>
#  </li>
#  <li class="counsel_list v2">
#  <strong class="tit_counsel_list">온라인상담</strong>
#  <ul class="counsel_info_list">
#  <li><a href="https://www.lifeline.or.kr" id="btn_suicide_stop" target="_blank">한국생명의전화</a></li>
#  <li><a href="https://www.cyber1388.kr:447" target="_blank">청소년사이버상담센터</a></li>
#  </ul>
#  </li>
#  <li class="counsel_list v3">
#  <strong class="tit_counsel_list">지식iN도 여러분을 돕습니다.</strong>
#  <ul class="counsel_info_list">
#  <li><a href="/qna/question.naver?expertType=doctor&amp;dirId=70109" target="_blank">의사에게질문하기</a></li>
#  <li><a href="/profile/index.naver?u=6oCfeacJKVQGwsBB7OHEIS4miiPixwQ%2FoueervNeYrg%3D" target="_blank">여성가족부. 한국청소년상담복지개발원</a></li>
#  <li><a href="/profile/index.naver?u=9xhBJX%2Fe3worDHM4Tp9d%2F4jUxoIMOWjkBn9VK4u3x8M%3D" target="_blank">경기도청소년상담복지센터</a></li>
#  <li class="list_aside"><a href="/profile/index.naver?u=m61fd7AyyTNGzdSXnfIARZMD2YrqU0TvSai8n3aIfHk%3D" target="_blank">마음상담</a></li>
#  <li><span class="counsel_vt">|</span><a href="/profile/index.naver?u=9AFcqSNT5xcmX%2BDwjqumdFA11U6ypJgxKXiNTqx%2FenU%3D" target="_blank">허그맘</a></li>
#  </ul>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <script type="text/javascript">
#  	jindo.$Fn(function() {
#
#
#  		if(nhn.Kin.Utility.containSuicideKeywords('\uC804\uC138\uC0AC\uAE30')) {
#
#  			jindo.$Element('suicidalPreventionBanner').show();
#  		}
#  	},this).attach(window,"load");
#  	</script>
#  <div class="section">
#  <h2>
#  <img alt="전체 지식iN" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/h_search_kin_all.gif" width="67"/>
#  <span class="number">(<em>1-10/177,123</em>)</span>
#  </h2>
#  <div class="option_search">
#  <ul class="option_sort">
#  <li class="sp_sort1"><strong><a aria-current="true" class="_nclicks:kin.relavant" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=kin&amp;sort=none" title="정확도"><span>정확도</span></a></strong></li>
#  <li class="sp_sort2"><a class="_nclicks:kin.recent" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=kin&amp;sort=date" title="최신순"><span>최신순</span></a></li>
#  <li class="sp_sort3"><a class="_nclicks:kin.vcount" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=kin&amp;sort=vcount" title="추천순"><span>추천순</span></a></li>
#  </ul>
#  <form name="date_search">
#  <input name="sort" type="hidden" value="none">
#  <input name="section" type="hidden" value="kin"/>
#  <input name="query" type="hidden" value="전세사기"/>
#  <input id="au_period" name="period" type="hidden" value=""/>
#  </input></form>
#  <ul class="option_term">
#  <li>
#  <div class="selectbox-noscript" id="au_date_select">
#  <select class="selectbox-source" id="au_date_result" name="date" title="기간 전체">
#  <option class="_nclicks:kin.dateall" selected="" value="0">기간 전체</option>
#  <option class="_nclicks:kin.date1w" value="1">최근 1주</option>
#  <option class="_nclicks:kin.date1m" value="2">최근 1달</option>
#  <option class="selectbox-notclose _nclicks:kin.dateinput" value="2002.01.01.2024.10.07.">기간 입력</option>
#  </select>
#  <div class="selectbox-box">
#  <div class="selectbox-label"></div>
#  </div>
#  <div class="selectbox-layer">
#  <div class="selectbox-list"></div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  <script src="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/js/min/nhn.Kin.Search.DateSelectBox.js" type="text/javascript"></script>
#  <script type="text/javascript">
#  			$Fn(function() {
#  				nhn.Kin.Search.DateSelectBox.initialize('PC');
#  			},this).attach(window,"load");
#
#  			</script>
#  </div>
#  <!-- Search List -->
#  <strong class="blind">검색결과</strong>
#  <ul class="basic1">
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60203&amp;docId=472283354&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><b>전세사기</b> 개인회생 신청알아보고 잇어요</a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53">
#  </img></dt>
#  <dd class="txt_inline">2024.09.11.</dd>
#  <dd><b>전세사기</b>를 당했어요., 인터넷카페 들어가보니. 상황이 좋지않은분들은 개인회생을 신청하면 된다고 해서 저도 정보알아보고 개인회생을 신청하려고 해요. 6천만원정도... </dd>
#  <dd class="tag_area">
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60203">신용, 파산</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 6</span> UP 17
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=459383821&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=2&amp;search_sort=0&amp;spq=0" target="_blank">세종<b>전세사기</b> 피해자인데요ㅠ</a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53">
#  </img></dt>
#  <dd class="txt_inline">2024.09.22.</dd>
#  <dd>세종<b>전세사기</b>로 지금 제 전세자금을 모두 잃을 판입니다ㅠㅠㅠㅠ 형사고소는 서둘러 했는데 전세자금 제대로 돌려받으려면 민사소송이 꼭 필요하다고 해서요ㅠㅠ 혹시... </dd>
#  <dd class="tag_area">
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60221">민사소송</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 4</span> UP 1
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=474817179&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=3&amp;search_sort=0&amp;spq=0" target="_blank"><b>전세사기</b> 민사소송</a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53"/>
#  </dt>
#  <dd class="txt_inline">2024.09.25.</dd>
#  <dd><b>전세사기</b>를 당해서 민사소송을 해야하나 생각중인데요 민사소송을 해야하는 이유가 있을까요?? 경매나 피해자인정 등등 변호사 비용도 만만치 않아서 고민되네요.. 안녕하세요.... </dd>
#  <dd class="tag_area">
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60221">민사소송</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 6</span> UP 2
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60203&amp;docId=467438873&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=4&amp;search_sort=0&amp;spq=0" target="_blank"><b>전세사기</b> 개인회생 대처방안 있을까요</a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53"/>
#  </dt>
#  <dd class="txt_inline">2024.09.02.</dd>
#  <dd>... 제가 얼마 전에 <b>전세사기</b>를 당했어서 <b>전세사기</b> 개인회생을 알아보고 있습니다. 근데 개인회생이 처음이라 도대체 뭐부터 해야할지 모르겠네요. 대학생도 신청이... </dd>
#  <dd class="tag_area">
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60203">신용, 파산</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 10</span> UP 43
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=458168484&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=5&amp;search_sort=0&amp;spq=0" target="_blank">수원<b>전세사기</b>변호사 선임 가능할까요</a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53"/>
#  </dt>
#  <dd class="txt_inline">2024.09.17.</dd>
#  <dd><b>전세사기</b>를 당해서 돈을 돌려받으려고 이것저것 찾아보고 있습니다. 손해배상 청구를 하려고 했는데 형사고소를 하면 돈도 받을 수 있다고 해서요. 그런데 이런 일이 처음이라... </dd>
#  <dd class="tag_area">
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60206">형사사건</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 7</span> UP 19
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=462896564&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=6&amp;search_sort=0&amp;spq=0" target="_blank">오피스텔<b>전세사기</b> 민사소송 진행해야... </a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53"/>
#  </dt>
#  <dd class="txt_inline">2024.09.27.</dd>
#  <dd>오피스텔<b>전세사기</b> 민사소송 진행해야 될까요? 깡통전세고 피의자는 현재 사기혐의로 고발당한 상황입니다 저는 지금 1억 8천만원의 보증금을 받지 못하고 있는데요 피해자만... </dd>
#  <dd class="tag_area">
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60221">민사소송</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 3</span> UP 1
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60203&amp;docId=475028213&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=7&amp;search_sort=0&amp;spq=0" target="_blank"><b>전세사기</b> 가해자</a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53"/>
#  </dt>
#  <dd class="txt_inline">2024.09.13.</dd>
#  <dd>제 아버지가 <b>전세사기</b> 가해자입니다. 현재 드려야할 보증금은 2000만원이고 이자도 붙은거 같아요. 오늘 어떤 분이 오셔서 저희 집 사진 찍고 뭐 작성하고 가셨어요. 경매로... </dd>
#  <dd class="tag_area">
#  <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EA%B0%9C%EC%9D%B8%ED%9A%8C%EC%83%9D&amp;listType=answer">#개인회생</a>
#  <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%EA%B0%80%ED%95%B4%EC%9E%90&amp;listType=answer">#전세사기가해자</a>
#  <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EA%B2%BD%EB%A7%A4%EB%84%98%EC%96%B4%EA%B0%80%EB%8A%94%EC%A7%91&amp;listType=answer">#경매넘어가는집</a>
#  <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%82%B0&amp;listType=answer">#파산</a>
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60203">신용, 파산</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 2</span> UP 1
#
#
#  								<span class="bar">|</span>
#
#
#  									답변
#
#
#
#  									민의홍 변호사(patm****)
#
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60223&amp;docId=476142501&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=8&amp;search_sort=0&amp;spq=0" target="_blank"><b>전세사기</b> 임차권등기신청 가능일자는... </a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53"/>
#  </dt>
#  <dd class="txt_inline">2024.10.04.</dd>
#  <dd><b>전세사기</b> 임차권등기신청 가능일자 전세계약종료일 24.10.16 공시송달 도달일 24.9.4 임차권등기는 전세계약 종료일 이후인 24.10.17 신청 가능한건가요 아니면 공시송달 도달... </dd>
#  <dd class="tag_area">
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60223">등기</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 1</span> UP 1
#
#
#  								<span class="bar">|</span>
#
#
#  									답변
#
#
#
#  									이종준변호사(ijy2****)
#
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=602060402&amp;docId=457657437&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=9&amp;search_sort=0&amp;spq=0" target="_blank">인천<b>전세사기</b>변호사 상담 받고 싶어요</a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53"/>
#  </dt>
#  <dd class="txt_inline">2024.10.02.</dd>
#  <dd>인천<b>전세사기</b>변호사 상담 원합니다. 지역은 인천이고 <b>전세사기</b> 당한 것 같습니다.. 계약만료일도 지났는데 주인이 보증금을 계속 안 돌려 주네요;; 갖은 핑계를 대면서 안 주고... </dd>
#  <dd class="tag_area">
#  <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%9D%B8%EC%B2%9C%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;listType=answer">#인천전세사기</a>
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=602060402">사기</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 7</span> UP 9
#
#
#  							</dd>
#  </dl>
#  </li>
#  <li>
#  <dl>
#  <dt>
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60211&amp;docId=468085229&amp;qb=7KCE7IS47IKs6riw&amp;enc=utf8§ion=kin.qna_ency&amp;rank=10&amp;search_sort=0&amp;spq=0" target="_blank">대구<b>전세사기</b> 당했습니다..</a>
#  <img alt="변호사답변" class="ico_pro" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/ico_proanswer_lawyer.gif" width="53"/>
#  </dt>
#  <dd class="txt_inline">2024.09.10.</dd>
#  <dd>대구<b>전세사기</b> 도와주세요... 뉴스에서만 봤는데, 저도 대구<b>전세사기</b> 당했습니다.. 대구<b>전세사기</b> 어떻게 해결해야 할까요..? 막막합니다. 최근 세입자들의 소중한 보증금을... </dd>
#  <dd class="tag_area">
#  <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EB%8C%80%EA%B5%AC%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;listType=answer">#대구전세사기</a>
#  </dd>
#  <dd class="txt_block">
#  <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna">Q&amp;A</a>
#
#  									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0§ion=qna&amp;dirId=60211">재판, 소송 절차</a>
#  <span class="bar">|</span>
#  <span class="hit">답변수 4</span> UP 4
#
#
#  							</dd>
#  </dl>
#  </li>
#  </ul>
#  <div class="s_paging">
#  <strong>1</strong>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=2" onclick="nhn.Kin.Utility.nClicks('kin.page','','2',event);">2</a>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=3" onclick="nhn.Kin.Utility.nClicks('kin.page','','3',event);">3</a>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=4" onclick="nhn.Kin.Utility.nClicks('kin.page','','4',event);">4</a>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=5" onclick="nhn.Kin.Utility.nClicks('kin.page','','5',event);">5</a>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=6" onclick="nhn.Kin.Utility.nClicks('kin.page','','6',event);">6</a>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=7" onclick="nhn.Kin.Utility.nClicks('kin.page','','7',event);">7</a>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=8" onclick="nhn.Kin.Utility.nClicks('kin.page','','8',event);">8</a>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=9" onclick="nhn.Kin.Utility.nClicks('kin.page','','9',event);">9</a>
#  <a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=10" onclick="nhn.Kin.Utility.nClicks('kin.page','','10',event);">10</a>
#  <a class="next _nclicks:kin.next" href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0&amp;page=11">다음페이지</a>
#  </div><!--kin:navigation maxPage="50" /-->
#  <script type="text/javascript">
#  				var kinSearchTerms = new nhn.Kin.Search.Terms();
#  				if (kinSearchTerms) {
#
#  					kinSearchTerms.addTerm('\uC804\uC138');
#
#  					kinSearchTerms.addTerm('\uC0AC\uAE30');
#
#  					kinSearchTerms.addQueryToTerm('\uC804\uC138\uC0AC\uAE30');
#  					var kin_terms = kinSearchTerms.makeTermArray();
#  				}
#  			</script>
#  <div class="this_questions" id="bottomQuestionButton">
#  <p>
#  <b class="keyword">'전세사기'</b> 에 대한 궁금증을 해결하지 못하셨다면 직접 질문해보세요!<br/>
#  				내 궁금증에 맞는 더 정확한 답변을 받을 수 있습니다.
#  			</p>
#  <a class="btn_go_question _nclicks:ask.question" href="/qna/question.naver" target="_blank" title="질문하러 가기"><img alt="질문하러 가기" height="33" src="https://ssl.pstatic.net/static/kin/09renewal/btn_go_question.gif" width="121"/></a>
#  </div>
#  <script type="text/javascript">
#
#  		$Fn(function() {
#  			if(nhn.Kin.Utility.containSuicideKeywords('\uC804\uC138\uC0AC\uAE30')) {
#  				$Element('bottomQuestionButton').hide();
#  			}
#  		},this).attach(window,"load");
#  		</script>
#  </div>
#  </div>
#  </div>
#  <div class="container-fluid-content__right">
#  <div id="aside">
#  <script src="https://ssl.pstatic.net/static.kin/static/pc/20240925134013/js/min/nhn.Kin.Search.RelatedKeyword.js" type="text/javascript"></script>
#  <div class="aside relate aside_type1" id="au_related_keyword">
#  <h4 class="h_side_title">
#  <strong class="tit">연관검색어</strong>
#  </h4>
#  <div class="aside_list aside_word">
#  <ul>
#  <li><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%ED%8A%B9%EB%B3%84%EB%B2%95">전세사기특별법</a></li>
#  <li><a href="/search/list.naver?query=%EB%8C%80%EC%A0%84%20%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%EC%82%AC%EB%AC%B4%EC%86%8C%20%EB%B2%95%EA%B0%95">대전 전세사기 사무소 법강</a></li>
#  <li><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%ED%94%BC%ED%95%B4%EC%9E%90%20%EC%8B%A0%EC%B2%AD">전세사기 피해자 신청</a></li>
#  <li><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%EB%B3%80%ED%98%B8%EC%82%AC">전세사기변호사</a></li>
#  <li><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%EC%98%88%EB%B0%A9">전세사기 예방</a></li>
#  <li><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%ED%94%BC%ED%95%B4%EC%9E%90">전세사기피해자</a></li>
#  <li><a href="/search/list.naver?query=%EC%95%84%ED%8C%8C%ED%8A%B8%20%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0">아파트 전세사기</a></li>
#  <li><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%EC%88%98%EB%B2%95">전세사기 수법</a></li>
#  <li><a href="/search/list.naver?query=%EB%B6%80%EC%82%B0%20%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0">부산 전세사기</a></li>
#  <li><a href="/search/list.naver?query=%EC%88%98%EC%9B%90%20%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0">수원 전세사기</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%9D%B8%EC%B2%9C%20%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0">인천 전세사기</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EA%B5%AC%EB%A6%AC%20%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0">구리 전세사기</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%ED%94%BC%ED%95%B4">전세사기 피해</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EB%8C%80%EA%B5%AC%20%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0">대구 전세사기</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EB%B9%8C%EB%9D%BC%20%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0">빌라 전세사기</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%EB%9C%BB">전세사기 뜻</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%ED%8C%90%EA%B2%B0">전세사기 판결</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%EA%B5%AC%EC%86%8D">전세사기 구속</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%20%EC%A7%95%EC%97%AD">전세사기 징역</a></li>
#  <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%A0%84%EC%84%B8%EC%82%AC%EA%B8%B0%ED%94%BC%ED%95%B4%EC%9E%90%20%ED%8A%B9%EB%B3%84%EB%B2%95">전세사기피해자 특별법</a></li>
#  </ul>
#  </div>
#  <div class="aside_help"><a class="cs" href="https://help.naver.com/service/5627/contents/4956" target="_blank"><span class="blind">연관검색어 </span>도움말</a><a class="cs2 _cs2" href="#"><span class="blind">연관검색어</span> <span>더보기 열기</span></a></div>
#  </div>
#  <div class="aside relate aside_type1" style="z-index:10">
#  <h4 class="h_side_title">
#  <strong class="tit">관련 분야</strong>
#  </h4>
#  <div class="aside_list" id="au_directory_list">
#  <ul>
#  <li><!-- 마우스 오버시 layer_on 클래스가 추가되어야 함 -->
#  <a href="/qna/list.naver?dirId=4020201" target="_blank">전세</a>
#  <div class="layer_base layer_popcate" style="top:15px; left:9px; display:none;">
#  <p>Q&amp;A&gt;경제&gt;부동산&gt;임대차&gt;전세</p>
#  </div>
#  </li>
#  <li><!-- 마우스 오버시 layer_on 클래스가 추가되어야 함 -->
#  <a href="/qna/list.naver?dirId=602060402" target="_blank">사기</a>
#  <div class="layer_base layer_popcate" style="top:15px; left:9px; display:none;">
#  <p>Q&amp;A&gt;사회, 정치&gt;법, 법률&gt;형사사건&gt;재산범죄&gt;사기</p>
#  </div>
#  </li>
#  <li><!-- 마우스 오버시 layer_on 클래스가 추가되어야 함 -->
#  <a href="/qna/list.naver?dirId=60214" target="_blank">형벌, 형집행</a>
#  <div class="layer_base layer_popcate" style="top:15px; left:9px; display:none;">
#  <p>Q&amp;A&gt;사회, 정치&gt;법, 법률&gt;형벌, 형집행</p>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <script type="text/javascript">
#  	nhn.Kin.Search.RelatedKeyword.initialize();
#  </script>
#  <div class="tag_area aside aside_type1">
#  <h4 class="h_side_title">관련태그</h4>
#  <div class="word_relate">
#  <ul class="relate_list">
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%A4%91%EA%B8%B0%EC%B2%AD&amp;listType=answer">#중기청</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EB%B3%B4%EC%A6%9D%EB%B3%B4%ED%97%98&amp;listType=answer">#보증보험</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=lh%EC%A0%84%EC%84%B8%EC%9E%84%EB%8C%80&amp;listType=answer">#lh전세임대</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%A0%84%EC%9E%85%EC%8B%A0%EA%B3%A0&amp;listType=answer">#전입신고</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%A0%84%EC%84%B8%EB%B3%B4%EC%A6%9D%EA%B8%88&amp;listType=answer">#전세보증금</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%8B%A0%ED%98%BC%EB%B6%80%EB%B6%80%EC%A0%84%EC%84%B8%EC%9E%90%EA%B8%88%EB%8C%80%EC%B6%9C&amp;listType=answer">#신혼부부전세자금대출</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=lh%EC%B2%AD%EB%85%84%EC%A0%84%EC%84%B8%EC%9E%84%EB%8C%80%EC%A3%BC%ED%83%9D&amp;listType=answer">#lh청년전세임대주택</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%B2%AD%EB%85%84%EC%A0%84%EC%84%B8%EC%9E%90%EA%B8%88%EB%8C%80%EC%B6%9C&amp;listType=answer">#청년전세자금대출</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%A0%84%EC%84%B8%EB%B3%B4%EC%A6%9D%EA%B8%88%EB%B0%98%ED%99%98&amp;listType=answer">#전세보증금반환</a></li>
#  <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%9D%B4%EC%82%AC&amp;listType=answer">#이사</a></li>
#  </ul>
#  </div>
#  </div>
#  <div class="aside aside_type1 noline">
#  <h4 class="h_side_title type_default">
#  <strong class="tit">아하!그렇구나</strong>
#  </h4>
#  <div class="aside_list">
#  <ul>
#  <li><a href="/qna/detail.naver?d1id=6&amp;dirId=6130103&amp;docId=475415693" target="_blank">추석에 송편을 먹는 이유</a></li>
#  <li><a href="/qna/detail.naver?d1id=11&amp;dirId=11080103&amp;docId=458209535" target="_blank">건넬때 or 건낼때 맞춤법...</a></li>
#  <li><a href="/qna/detail.naver?d1id=8&amp;dirId=816&amp;docId=462380384" target="_blank">미국에서 문자로 대화할때...</a></li>
#  <li><a href="/qna/detail.naver?d1id=8&amp;dirId=802&amp;docId=471796953" target="_blank">부리또볼과 포케 차이</a></li>
#  <li><a href="/qna/detail.naver?d1id=11&amp;dirId=110204&amp;docId=458353443" target="_blank">폭염에 이글이글(?)거리는...</a></li>
#  </ul>
#  </div>
#  <span class="more"><a href="/best/listaha.naver">더보기</a></span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <script>
#  	var query = '\uC804\uC138\uC0AC\uAE30';
#  	if (query) {
#  		sendBaLog(BaPcEventType.KIN_SEARCH_5064, {keyword: query});
#  	}
#  </script>
#  </div>
#  <footer class="footerArea">
#  <div class="footerList">
#  <a class="footerItem _nclicks:fot.agreement" href="http://www.naver.com/rules/service.html" target="_blank">이용약관</a>
#  <a class="footerItem _nclicks:fot.policy" href="/common/guide.naver?query=p1" target="_blank">지식iN 서비스 운영정책</a>
#  <a class="footerItem _nclicks:fot.privacy" href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
#  <a class="footerItem _nclicks:fot.claim" href="https://right.naver.com" target="_blank">권리보호센터</a>
#  <a class="footerItem _nclicks:fot.help" href="https://help.naver.com/alias/kin/kinmain.naver" target="_faqhelp">지식iN 고객센터</a>
#  <address class="copyright"><a class="highlight _nclicks:fot.nhncorp" href="https://www.navercorp.com" target="_openNHNWindow">© NAVER Corp.</a></address>
#  </div>
#  </footer>
#  <script type="text/javascript">
#
#
#  	lcs_do();
#
#  </script>
#  </body>
#  </html>)

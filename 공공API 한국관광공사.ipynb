# %%
import requests
import pandas as pd

# %%
KEY='FPTew6zWGEAkHvVT0EdIhjmJAXNUsMb5qjSqAhCEjk15KaFEamuElzD4EXmAd73fw7e3lw97x6SpUUnpXQDJsg%3D%3D'
s_d='20230101'
e_d='20231224'
url1='http://apis.data.go.kr/B551011/KorService1/searchFestival1?serviceKey='+KEY
url2='&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=json&listYN=Y&arrange=A&eventStartDate='+s_d
url3='&eventEndDate='+e_d

url=url1+url2+url3
url
# Out:
# 'http://apis.data.go.kr/B551011/KorService1/searchFestival1?serviceKey=FPTew6zWGEAkHvVT0EdIhjmJAXNUsMb5qjSqAhCEjk15KaFEamuElzD4EXmAd73fw7e3lw97x6SpUUnpXQDJsg%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=json&listYN=Y&arrange=A&eventStartDate=20230101&eventEndDate=20231224'

# %%
response=requests.get(url).json()
response
# Out:
# {'response': {'header': {'resultCode': '0000', 'resultMsg': 'OK'},
#   'body': {'items': {'item': [{'addr1': '강원특별자치도 강릉시 경강로 2111 (임당동)',
#       'addr2': '강릉 월화거리',
#       'booktour': '',
#       'cat1': 'A02',
#       'cat2': 'A0207',
#       'cat3': 'A02070200',
#       'contentid': '2926577',
#       'contenttypeid': '15',
#       'createdtime': '20221201113622',
#       'eventstartdate': '20231102',
#       'eventenddate': '20231104',
#       'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/27/3019027_image2_1.jpg',
#       'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/27/3019027_image3_1.jpg',
#       'cpyrhtDivCd': 'Type3',
#       'mapx': '128.8976276267',
#       'mapy': '37.7558321116',
#       'mlevel': '6',
#       'modifiedtime': '20240206130654',
#       'areacode': '32',
#       'sigungucode': '1',
#       'tel': '033-647-6802',
#       'title': '강릉와인축제'},
#      {'addr1': '강원특별자치도 평창군 진부면 경강로 3554',
#       'addr2': '',
#       'booktour': '',
# ...

# %%
df=pd.DataFrame(response['response']['body']['items']['item'])

# %%
print(df.shape)
df.head()
# Out:
# (199, 22)
#                           addr1    addr2 booktour cat1   cat2       cat3  \
# 0    강원특별자치도 강릉시 경강로 2111 (임당동)  강릉 월화거리           A02  A0207  A02070200
# 1      강원특별자치도 평창군 진부면 경강로 3554                    A02  A0208  A02081300
# 2            강원특별자치도 춘천시 서면 현암리      875           A02  A0208  A02081300
# 3   인천광역시 강화군 송해면 전망대로423번길 161    양오낚시터           A02  A0207  A02070200
# 4  인천광역시 강화군 중앙로787번길 8-1 관리소매점                    A02  A0207  A02070200
#
#   contentid contenttypeid     createdtime eventstartdate  ...  \
# 0   2926577            15  20221201113622       20231102  ...
# 1   3011891            15  20230918113909       20230921  ...
# 2   3033914            15  20231108092605       20231118  ...
# 3   2643189            15  20200109003349       20231223  ...
# 4   2938676            15  20221222175030       20231220  ...
#
#                                          firstimage2 cpyrhtDivCd  \
# 0  http://tong.visitkorea.or.kr/cms/resource/27/3...       Type3
# ...

# %%
# 'https://apis.data.go.kr/B551011/KorService1/searchFestival1?serviceKey=FPTew6zWGEAkHvVT0EdIhjmJAXNUsMb5qjSqAhCEjk15KaFEamuElzD4EXmAd73fw7e3lw97x6SpUUnpXQDJsg%3D%3D&numOfRows=10&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=json&listYN=Y&arrange=A&eventStartDate=20170901'

url='http://apis.data.go.kr/B551011/KorService1/searchFestival1'
p={
    'serviceKey':'FPTew6zWGEAkHvVT0EdIhjmJAXNUsMb5qjSqAhCEjk15KaFEamuElzD4EXmAd73fw7e3lw97x6SpUUnpXQDJsg==',
    'numOfRows': 1000,
    'pageNo':1,
    'MobileOS':'ETC',
    'MobileApp':'AppTest',
    '_type':'json',
    'listYN':'Y',
    'arrange':'A',
    'eventStartDate':'20230101',
    'eventEndDate':'20231231'
}

res=requests.get(url,params=p).json()
res
# Out:
# {'response': {'header': {'resultCode': '0000', 'resultMsg': 'OK'},
#   'body': {'items': {'item': [{'addr1': '강원특별자치도 강릉시 경강로 2111 (임당동)',
#       'addr2': '강릉 월화거리',
#       'booktour': '',
#       'cat1': 'A02',
#       'cat2': 'A0207',
#       'cat3': 'A02070200',
#       'contentid': '2926577',
#       'contenttypeid': '15',
#       'createdtime': '20221201113622',
#       'eventstartdate': '20231102',
#       'eventenddate': '20231104',
#       'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/27/3019027_image2_1.jpg',
#       'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/27/3019027_image3_1.jpg',
#       'cpyrhtDivCd': 'Type3',
#       'mapx': '128.8976276267',
#       'mapy': '37.7558321116',
#       'mlevel': '6',
#       'modifiedtime': '20240206130654',
#       'areacode': '32',
#       'sigungucode': '1',
#       'tel': '033-647-6802',
#       'title': '강릉와인축제'},
#      {'addr1': '강원특별자치도 평창군 진부면 경강로 3554',
#       'addr2': '',
#       'booktour': '',
# ...
